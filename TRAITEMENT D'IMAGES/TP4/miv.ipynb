# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

image = np.ones((8, 6)) * 150
image[:-2, :3] = 50

plt.imshow(image, cmap='gray')

# %%
laplacian = cv.Laplacian(image, cv.CV_64F)
plt.imshow(laplacian, cmap='gray')

# %%
laplacian[laplacian < 0] = 0
plt.imshow(laplacian, cmap='gray')

# %%
harris_matrix = cv.cornerHarris(image, 2, 3, 0.04)
plt.imshow(harris_matrix, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 harris_matrix = cv.cornerHarris(image, 2, 3, 0.04)
#       2 plt.imshow(harris_matrix, cmap='gray')
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\corner.cpp:254: error: (-215:Assertion failed) src.type() == CV_8UC1 || src.type() == CV_32FC1 in function 'cv::cornerEigenValsVecs'
