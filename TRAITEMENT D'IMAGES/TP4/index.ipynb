# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Code from:
# https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_feature2d/py_matcher/py_matcher.html

# Prepared for M1IV students, by Prof. Slimane Larabi
#===================================================

# %%
img1 = cv2.imread('papa.png',0)          # queryImage
img2 = cv2.imread('kaaba.jpg',0) # trainImage

sift = cv2.SIFT_create()

kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# %%
des1.shape
# Out:
# (428, 128)

# %%
# BFMatcher with default params

# create BFMatcher object
bf = cv2.BFMatcher()

# Match descriptors.
matches = bf.match(des1,des2)

# sort the matches based on distance
matches = sorted(matches, key=lambda val: val.distance)

img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:5], None, flags=2)

plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x195267bb200>, None)

# %%
len(matches)
matches[0].queryIdx
# Out:
# 220

# %%
matches = sorted(matches, key=lambda val: val.distance)

img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], None, flags=2)

plt.imshow(img3)
plt.show()

# %%
image_original = cv2.imread('papa.png')

# %%
b, g, r = cv2.split(image_original)

# %%
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(r, cmap='gray')
plt.title('Red Channel')
plt.subplot(132)
plt.imshow(g, cmap='gray')
plt.title('Green Channel')
plt.subplot(133)
plt.imshow(b, cmap='gray')
plt.title('Blue Channel')
plt.show()

# %%
for channel in cv2.split(image_original):
    sift = cv2.SIFT_create()
    kp, des = sift.detectAndCompute(channel, None)

# %%
descriptors = []
for channel in cv2.split(image_original):
    sift = cv2.SIFT_create()
    kp, des = sift.detectAndCompute(channel, None)
    print(des.shape)
    plt.imshow(des.T)
    plt.show()
# Out:
# (414, 128)
# (438, 128)
# (417, 128)
