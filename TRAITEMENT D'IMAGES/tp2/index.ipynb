# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
peroquet = cv.imread('perroquet-ara-133925.jpg', cv.IMREAD_GRAYSCALE)

hist = cv.calcHist([peroquet],[0],None,[256],[0,256]) 
  
plt.plot(hist, color='b')

# %%
threshold = hist.argmax()

# %%
threshold
# Out:
# 21
